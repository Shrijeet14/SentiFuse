# %%
# !pip install mlflow dagshub  lightgbm
# Out:
# Collecting mlflow
#   Downloading mlflow-3.1.0-py3-none-any.whl.metadata (29 kB)
# Collecting dagshub
#   Downloading dagshub-0.5.10-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Collecting mlflow-skinny==3.1.0 (from mlflow)
#   Downloading mlflow_skinny-3.1.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.1.1)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.16.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.0.2)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pyarrow<21,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow) (18.1.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.11/dist-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.11/dist-packages (from mlflow) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.0.41)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (3.1.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.1.0->mlflow)
#   Downloading databricks_sdk-0.57.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: fastapi<1 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (0.115.12)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (8.7.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.1.0->mlflow)
#   Downloading opentelemetry_api-1.34.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.1.0->mlflow)
#   Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging<26 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (5.29.5)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (2.11.7)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (4.14.0)
# Requirement already satisfied: uvicorn<1 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.0->mlflow) (0.34.3)
# Collecting appdirs>=1.4.4 (from dagshub)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from dagshub) (0.28.1)
# Requirement already satisfied: rich>=13.1.0 in /usr/local/lib/python3.11/dist-packages (from dagshub) (13.9.4)
# Collecting dacite~=1.6.0 (from dagshub)
#   Downloading dacite-1.6.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: tenacity>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from dagshub) (9.1.2)
# Collecting gql[requests] (from dagshub)
#   Downloading gql-3.5.3-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting dataclasses-json (from dagshub)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting treelib>=1.6.4 (from dagshub)
#   Downloading treelib-1.7.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting pathvalidate>=3.0.0 (from dagshub)
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from dagshub) (2.9.0.post0)
# Collecting boto3 (from dagshub)
#   Downloading boto3-1.38.41-py3-none-any.whl.metadata (6.6 kB)
# Collecting semver (from dagshub)
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Collecting dagshub-annotation-converter>=0.1.5 (from dagshub)
#   Downloading dagshub_annotation_converter-0.1.10-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic!=1.10.0,<2->mlflow) (1.1.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from dagshub-annotation-converter>=0.1.5->dagshub) (5.4.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from dagshub-annotation-converter>=0.1.5->dagshub) (11.2.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from docker<8,>=4.0.0->mlflow) (2.4.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.1.0->mlflow) (4.0.12)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->dagshub) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->dagshub) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->dagshub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->dagshub) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.23.0->dagshub) (0.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->dagshub) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.1.0->dagshub) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.1.0->dagshub) (2.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.3)
# Collecting botocore<1.39.0,>=1.38.41 (from boto3->dagshub)
#   Downloading botocore-1.38.41-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->dagshub)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3->dagshub)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->dagshub)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->dagshub)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: yarl<2.0,>=1.6 in /usr/local/lib/python3.11/dist-packages (from gql[requests]->dagshub) (1.20.1)
# Collecting backoff<3.0,>=1.11.1 (from gql[requests]->dagshub)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests-toolbelt<2,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from gql[requests]->dagshub) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.23.0->dagshub) (1.3.1)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.11/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->mlflow) (2.38.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi<1->mlflow-skinny==3.1.0->mlflow) (0.46.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.1.0->mlflow) (5.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.1.0->mlflow) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.1.0->dagshub) (0.1.2)
# Collecting opentelemetry-semantic-conventions==0.55b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.1.0->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.0->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.0->mlflow) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.0->mlflow) (3.4.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->dagshub)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.6->gql[requests]->dagshub) (6.4.4)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.6->gql[requests]->dagshub) (0.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->mlflow) (4.9.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->mlflow) (0.6.1)
# Downloading mlflow-3.1.0-py3-none-any.whl (24.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 42.6 MB/s eta 0:00:00
# Downloading mlflow_skinny-3.1.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 48.0 MB/s eta 0:00:00
# Downloading dagshub-0.5.10-py3-none-any.whl (260 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 21.1 MB/s eta 0:00:00
# Downloading alembic-1.16.2-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 9.6 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading dacite-1.6.0-py3-none-any.whl (12 kB)
# Downloading dagshub_annotation_converter-0.1.10-py3-none-any.whl (33 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 8.0 MB/s eta 0:00:00
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 10.4 MB/s eta 0:00:00
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 7.8 MB/s eta 0:00:00
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Downloading treelib-1.7.1-py3-none-any.whl (19 kB)
# Downloading boto3-1.38.41-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 13.1 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading botocore-1.38.41-py3-none-any.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 50.6 MB/s eta 0:00:00
# Downloading databricks_sdk-0.57.0-py3-none-any.whl (733 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.8/733.8 kB 21.4 MB/s eta 0:00:00
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 17.2 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.6 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.34.1-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 5.9 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 11.3 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 16.2 MB/s eta 0:00:00
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 8.0 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading gql-3.5.3-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 7.7 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: appdirs, treelib, semver, pathvalidate, mypy-extensions, marshmallow, jmespath, gunicorn, graphql-core, dacite, backoff, typing-inspect, opentelemetry-api, graphql-relay, gql, docker, botocore, alembic, s3transfer, opentelemetry-semantic-conventions, graphene, dataclasses-json, databricks-sdk, dagshub-annotation-converter, opentelemetry-sdk, boto3, mlflow-skinny, dagshub, mlflow
# Successfully installed alembic-1.16.2 appdirs-1.4.4 backoff-2.2.1 boto3-1.38.41 botocore-1.38.41 dacite-1.6.0 dagshub-0.5.10 dagshub-annotation-converter-0.1.10 databricks-sdk-0.57.0 dataclasses-json-0.6.7 docker-7.1.0 gql-3.5.3 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 jmespath-1.0.1 marshmallow-3.26.1 mlflow-3.1.0 mlflow-skinny-3.1.0 mypy-extensions-1.1.0 opentelemetry-api-1.34.1 opentelemetry-sdk-1.34.1 opentelemetry-semantic-conventions-0.55b1 pathvalidate-3.3.1 s3transfer-0.13.0 semver-3.0.4 treelib-1.7.1 typing-inspect-0.9.0

# %%
import mlflow
import dagshub

dagshub.init(repo_owner='Shrijeet14', repo_name='Comment-Analyzer', mlflow=True)

mlflow.set_tracking_uri("https://dagshub.com/Shrijeet14/Comment-Analyzer.mlflow/")
# Out:
#                                        ❗❗❗ AUTHORIZATION REQUIRED ❗❗❗
# Output()
# Open the following link in your browser to authorize the client:
# https://dagshub.com/login/oauth/authorize?state=2bfefeea-0efe-489d-98ae-cf8d7067fddf&client_id=32b60ba385aa7cecf24046d8195a71c07dd345d9657977863b52e7748e0f0f28&middleman_request_id=eb643f74feb2fbcc53887fae0c158900ec66457170587913c1b3d888413923c9
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Accessing as Shrijeet14
# Initialized MLflow to track repo "Shrijeet14/Comment-Analyzer"
# Repository Shrijeet14/Comment-Analyzer initialized!

# %%
mlflow.set_experiment("V2_Final_Deployment_Model_Training")
# Out:
# 2025/06/22 23:34:16 INFO mlflow.tracking.fluent: Experiment with name 'V2_Final_Deployment_Model_Training' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/3e19fdbdb4b14a2b9eebe3b5c9504940', creation_time=1750635256707, experiment_id='8', last_update_time=1750635256707, lifecycle_stage='active', name='V2_Final_Deployment_Model_Training', tags={}>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, f1_score
from tqdm import tqdm
import mlflow
import mlflow.sklearn
import dagshub
import openai
import joblib
import os
import time
import warnings

warnings.filterwarnings("ignore")

# Set your OpenAI API key
openai.api_key = "Your api key"

# %%
# Load and clean data
dataset = pd.read_csv('/content/reddit_preprocessing.csv')
cleaned_dataset = dataset.dropna()
X = cleaned_dataset['clean_comment'].tolist()
y = cleaned_dataset['category']

# Function to get OpenAI embeddings in batch
def get_openai_embeddings_batch(text_batch, model="text-embedding-3-small"):
    try:
        response = openai.embeddings.create(input=text_batch, model=model)
        return [np.array(item.embedding) for item in response.data]
    except Exception as e:
        print(" Error during batch embedding:", e)
        return None

# Generate embeddings with batching
batch_size = 100
X_embeddings = []

print(" Generating OpenAI embeddings in batches...")
for i in tqdm(range(0, len(X), batch_size), desc="Embedding Batches"):
    batch_texts = X[i:i + batch_size]
    embeddings = get_openai_embeddings_batch(batch_texts)
    if embeddings is not None:
        X_embeddings.extend(embeddings)
    else:
        print(f" Skipping batch {i}-{i + batch_size} due to error")
    time.sleep(0.5)  # Optional: avoid rate limit

X_embeddings = np.array(X_embeddings)
np.save("openai_embeddings.npy", X_embeddings)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_embeddings, y, test_size=0.2, random_state=42)

# Define base learners
lightgbm_model = LGBMClassifier(
    device='gpu',
    boosting_type='gbdt',
    objective='multiclass',
    num_class=3,
    metric="multi_logloss",
    is_unbalance=True,
    class_weight="balanced",
    reg_alpha=0.1,
    reg_lambda=0.1,
    learning_rate=0.08081298097796712,
    n_estimators=367,
    max_depth=20,
    n_jobs=-1,
    verbose=-1
)

logreg_model = LogisticRegression(
    max_iter=1000,
    class_weight='balanced',
    solver='lbfgs',
    multi_class='multinomial',
    n_jobs=-1
)

# Meta learner (XGBoost with GPU)
xgb_meta = XGBClassifier(
    tree_method='gpu_hist',
    use_label_encoder=False,
    eval_metric='mlogloss'
)

# Stacking model
stacking_model = StackingClassifier(
    estimators=[
        ('lightgbm', lightgbm_model),
        ('logistic_regression', logreg_model)
    ],
    final_estimator=xgb_meta,
    n_jobs=-1,
    cv=5
)

# MLflow tracking
with mlflow.start_run(run_name="Stacking_with_OpenAI_Embeddings"):
    mlflow.log_param("embedding_model", "text-embedding-3-small")
    mlflow.log_param("lightgbm_learning_rate", 0.0808)
    mlflow.log_param("lightgbm_n_estimators", 367)
    mlflow.log_param("logreg_max_iter", 1000)
    mlflow.log_param("meta_learner", "XGBoost-GPU")

    print("Training Stacking Model...")
    for _ in tqdm(range(1), desc="Fitting model"):
        stacking_model.fit(X_train, y_train)

    y_pred = stacking_model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')
    mlflow.log_metric("accuracy", acc)
    mlflow.log_metric("f1_score_weighted", f1)

    report = classification_report(y_test, y_pred)
    with open("classification_report.txt", "w") as f:
        f.write(report)
    mlflow.log_artifact("classification_report.txt")

    joblib.dump(stacking_model, "Final_Model.pkl")
    mlflow.log_artifact("Final_Model.pkl")

    mlflow.log_artifact("openai_embeddings.npy")

    cleaned_dataset.to_csv("used_dataset.csv", index=False)
    mlflow.log_artifact("used_dataset.csv")

print(report)
# Out:
# 🚀 Generating OpenAI embeddings in batches...
# Embedding Batches:   0%|          | 0/367 [00:00<?, ?it/s]
#
# Embedding Batches:   0%|          | 1/367 [00:01<08:57,  1.47s/it]
#
# Embedding Batches:   1%|          | 2/367 [00:02<08:03,  1.33s/it]
#
# Embedding Batches:   1%|          | 3/367 [00:03<07:44,  1.28s/it]
#
# Embedding Batches:   1%|          | 4/367 [00:05<07:44,  1.28s/it]
#
# Embedding Batches:   1%|▏         | 5/367 [00:06<07:58,  1.32s/it]
#
# Embedding Batches:   2%|▏         | 6/367 [00:07<07:38,  1.27s/it]
#
# Embedding Batches:   2%|▏         | 7/367 [00:09<07:43,  1.29s/it]
#
# Embedding Batches:   2%|▏         | 8/367 [00:10<08:00,  1.34s/it]
#
# Embedding Batches:   2%|▏         | 9/367 [00:11<07:38,  1.28s/it]
#
# Embedding Batches:   3%|▎         | 10/367 [00:12<07:32,  1.27s/it]
#
# Embedding Batches:   3%|▎         | 11/367 [00:14<07:53,  1.33s/it]
#
# Embedding Batches:   3%|▎         | 12/367 [00:16<08:23,  1.42s/it]
#
# Embedding Batches:   4%|▎         | 13/367 [00:17<08:05,  1.37s/it]
#
# Embedding Batches:   4%|▍         | 14/367 [00:18<07:59,  1.36s/it]
#
# Embedding Batches:   4%|▍         | 15/367 [00:20<08:01,  1.37s/it]
#
# Embedding Batches:   4%|▍         | 16/367 [00:21<07:37,  1.30s/it]
#
# Embedding Batches:   5%|▍         | 17/367 [00:22<07:37,  1.31s/it]
#
# Embedding Batches:   5%|▍         | 18/367 [00:23<07:34,  1.30s/it]
#
# Embedding Batches:   5%|▌         | 19/367 [00:25<07:59,  1.38s/it]
#
# Embedding Batches:   5%|▌         | 20/367 [00:26<07:52,  1.36s/it]
#
# Embedding Batches:   6%|▌         | 21/367 [00:28<07:57,  1.38s/it]
#
# Embedding Batches:   6%|▌         | 22/367 [00:29<07:48,  1.36s/it]
#
# Embedding Batches:   6%|▋         | 23/367 [00:30<08:03,  1.41s/it]
#
# Embedding Batches:   7%|▋         | 24/367 [00:32<08:12,  1.44s/it]
#
# Embedding Batches:   7%|▋         | 25/367 [00:33<08:10,  1.44s/it]
#
# Embedding Batches:   7%|▋         | 26/367 [00:35<07:54,  1.39s/it]
#
# Embedding Batches:   7%|▋         | 27/367 [00:37<08:48,  1.56s/it]
#
# Embedding Batches:   8%|▊         | 28/367 [00:38<08:12,  1.45s/it]
#
# Embedding Batches:   8%|▊         | 29/367 [00:39<08:18,  1.47s/it]
#
# Embedding Batches:   8%|▊         | 30/367 [00:41<08:08,  1.45s/it]
#
# Embedding Batches:   8%|▊         | 31/367 [00:42<08:08,  1.46s/it]
#
# Embedding Batches:   9%|▊         | 32/367 [00:44<08:04,  1.45s/it]
#
# Embedding Batches:   9%|▉         | 33/367 [00:45<07:46,  1.40s/it]
#
# Embedding Batches:   9%|▉         | 34/367 [00:46<07:40,  1.38s/it]
#
# Embedding Batches:  10%|▉         | 35/367 [00:48<07:35,  1.37s/it]
#
# Embedding Batches:  10%|▉         | 36/367 [00:49<07:17,  1.32s/it]
#
# Embedding Batches:  10%|█         | 37/367 [00:50<07:12,  1.31s/it]
#
# Embedding Batches:  10%|█         | 38/367 [00:51<06:44,  1.23s/it]
#
#   0%|          | 0/36662 [25:00<?, ?it/s]
#
#
# Embedding Batches:  11%|█         | 40/367 [00:54<07:49,  1.44s/it]
#
# Embedding Batches:  11%|█         | 41/367 [00:56<07:43,  1.42s/it]
#
# Embedding Batches:  11%|█▏        | 42/367 [00:57<07:36,  1.41s/it]
#
# Embedding Batches:  12%|█▏        | 43/367 [00:58<07:26,  1.38s/it]
#
# Embedding Batches:  12%|█▏        | 44/367 [01:00<07:22,  1.37s/it]
#
# Embedding Batches:  12%|█▏        | 45/367 [01:01<07:00,  1.31s/it]
#
# Embedding Batches:  13%|█▎        | 46/367 [01:03<07:45,  1.45s/it]
#
# Embedding Batches:  13%|█▎        | 47/367 [01:04<07:01,  1.32s/it]
#
# Embedding Batches:  13%|█▎        | 48/367 [01:05<07:22,  1.39s/it]
#
# Embedding Batches:  13%|█▎        | 49/367 [01:06<07:13,  1.36s/it]
#
# Embedding Batches:  14%|█▎        | 50/367 [01:08<07:09,  1.35s/it]
#
# Embedding Batches:  14%|█▍        | 51/367 [01:09<06:55,  1.31s/it]
#
# Embedding Batches:  14%|█▍        | 52/367 [01:10<06:47,  1.29s/it]
#
# Embedding Batches:  14%|█▍        | 53/367 [01:12<06:47,  1.30s/it]
#
# Embedding Batches:  15%|█▍        | 54/367 [01:13<06:47,  1.30s/it]
#
# Embedding Batches:  15%|█▍        | 55/367 [01:14<06:43,  1.29s/it]
#
# Embedding Batches:  15%|█▌        | 56/367 [01:16<07:06,  1.37s/it]
#
# Embedding Batches:  16%|█▌        | 57/367 [01:17<06:59,  1.35s/it]
#
# Embedding Batches:  16%|█▌        | 58/367 [01:19<07:09,  1.39s/it]
#
# Embedding Batches:  16%|█▌        | 59/367 [01:20<07:24,  1.44s/it]
#
# Embedding Batches:  16%|█▋        | 60/367 [01:21<06:42,  1.31s/it]
#
# Embedding Batches:  17%|█▋        | 61/367 [01:22<06:49,  1.34s/it]
#
# Embedding Batches:  17%|█▋        | 62/367 [01:24<07:10,  1.41s/it]
#
# Embedding Batches:  17%|█▋        | 63/367 [01:25<07:03,  1.39s/it]
#
# Embedding Batches:  17%|█▋        | 64/367 [01:27<06:41,  1.32s/it]
#
# Embedding Batches:  18%|█▊        | 65/367 [01:28<07:21,  1.46s/it]
#
# Embedding Batches:  18%|█▊        | 66/367 [01:30<07:14,  1.44s/it]
#
# Embedding Batches:  18%|█▊        | 67/367 [01:32<07:38,  1.53s/it]
#
# Embedding Batches:  19%|█▊        | 68/367 [01:33<07:10,  1.44s/it]
#
# Embedding Batches:  19%|█▉        | 69/367 [01:35<07:41,  1.55s/it]
#
# Embedding Batches:  19%|█▉        | 70/367 [01:36<07:38,  1.54s/it]
#
# Embedding Batches:  19%|█▉        | 71/367 [01:37<07:22,  1.50s/it]
#
# Embedding Batches:  20%|█▉        | 72/367 [01:39<07:15,  1.48s/it]
#
# Embedding Batches:  20%|█▉        | 73/367 [01:40<06:58,  1.42s/it]
#
# Embedding Batches:  20%|██        | 74/367 [01:42<06:48,  1.39s/it]
#
# Embedding Batches:  20%|██        | 75/367 [01:43<06:27,  1.33s/it]
#
# Embedding Batches:  21%|██        | 76/367 [01:44<06:08,  1.27s/it]
#
# Embedding Batches:  21%|██        | 77/367 [01:45<06:24,  1.33s/it]
#
# Embedding Batches:  21%|██▏       | 78/367 [01:47<06:23,  1.33s/it]
#
# Embedding Batches:  22%|██▏       | 79/367 [01:48<06:28,  1.35s/it]
#
# Embedding Batches:  22%|██▏       | 80/367 [01:49<06:33,  1.37s/it]
#
# Embedding Batches:  22%|██▏       | 81/367 [01:51<06:35,  1.38s/it]
#
# Embedding Batches:  22%|██▏       | 82/367 [01:53<07:09,  1.51s/it]
#
# Embedding Batches:  23%|██▎       | 83/367 [01:55<07:40,  1.62s/it]
#
# Embedding Batches:  23%|██▎       | 84/367 [01:56<07:14,  1.54s/it]
#
# Embedding Batches:  23%|██▎       | 85/367 [01:57<06:57,  1.48s/it]
#
# Embedding Batches:  23%|██▎       | 86/367 [01:59<06:41,  1.43s/it]
#
# Embedding Batches:  24%|██▎       | 87/367 [02:00<06:32,  1.40s/it]
#
# Embedding Batches:  24%|██▍       | 88/367 [02:01<06:20,  1.36s/it]
#
# Embedding Batches:  24%|██▍       | 89/367 [02:02<06:12,  1.34s/it]
#
# Embedding Batches:  25%|██▍       | 90/367 [02:04<06:02,  1.31s/it]
#
# Embedding Batches:  25%|██▍       | 91/367 [02:05<06:41,  1.45s/it]
#
# Embedding Batches:  25%|██▌       | 92/367 [02:07<06:38,  1.45s/it]
#
# Embedding Batches:  25%|██▌       | 93/367 [02:08<06:09,  1.35s/it]
#
# Embedding Batches:  26%|██▌       | 94/367 [02:09<06:07,  1.34s/it]
#
# Embedding Batches:  26%|██▌       | 95/367 [02:10<05:42,  1.26s/it]
#
# Embedding Batches:  26%|██▌       | 96/367 [02:11<05:22,  1.19s/it]
#
# Embedding Batches:  26%|██▋       | 97/367 [02:13<05:35,  1.24s/it]
#
# Embedding Batches:  27%|██▋       | 98/367 [02:14<05:42,  1.27s/it]
#
# Embedding Batches:  27%|██▋       | 99/367 [02:16<05:56,  1.33s/it]
#
# Embedding Batches:  27%|██▋       | 100/367 [02:17<05:43,  1.29s/it]
#
# Embedding Batches:  28%|██▊       | 101/367 [02:18<05:50,  1.32s/it]
#
# Embedding Batches:  28%|██▊       | 102/367 [02:19<05:48,  1.31s/it]
#
# Embedding Batches:  28%|██▊       | 103/367 [02:21<05:53,  1.34s/it]
#
# Embedding Batches:  28%|██▊       | 104/367 [02:22<05:47,  1.32s/it]
#
# Embedding Batches:  29%|██▊       | 105/367 [02:23<05:37,  1.29s/it]
#
# Embedding Batches:  29%|██▉       | 106/367 [02:24<05:13,  1.20s/it]
#
# Embedding Batches:  29%|██▉       | 107/367 [02:26<05:19,  1.23s/it]
#
# Embedding Batches:  29%|██▉       | 108/367 [02:27<05:43,  1.33s/it]
#
# Embedding Batches:  30%|██▉       | 109/367 [02:28<05:34,  1.30s/it]
#
# Embedding Batches:  30%|██▉       | 110/367 [02:30<05:39,  1.32s/it]
#
# Embedding Batches:  30%|███       | 111/367 [02:31<05:45,  1.35s/it]
#
# Embedding Batches:  31%|███       | 112/367 [02:32<05:33,  1.31s/it]
#
# Embedding Batches:  31%|███       | 113/367 [02:34<05:45,  1.36s/it]
#
# Embedding Batches:  31%|███       | 114/367 [02:35<05:41,  1.35s/it]
#
# Embedding Batches:  31%|███▏      | 115/367 [02:36<05:25,  1.29s/it]
#
# Embedding Batches:  32%|███▏      | 116/367 [02:38<05:23,  1.29s/it]
#
# Embedding Batches:  32%|███▏      | 117/367 [02:39<05:22,  1.29s/it]
#
# Embedding Batches:  32%|███▏      | 118/367 [02:40<05:16,  1.27s/it]
#
# Embedding Batches:  32%|███▏      | 119/367 [02:41<05:14,  1.27s/it]
#
# Embedding Batches:  33%|███▎      | 120/367 [02:43<05:13,  1.27s/it]
#
# Embedding Batches:  33%|███▎      | 121/367 [02:44<05:19,  1.30s/it]
#
# Embedding Batches:  33%|███▎      | 122/367 [02:45<05:23,  1.32s/it]
#
# Embedding Batches:  34%|███▎      | 123/367 [02:47<05:24,  1.33s/it]
#
# Embedding Batches:  34%|███▍      | 124/367 [02:48<05:20,  1.32s/it]
#
# Embedding Batches:  34%|███▍      | 125/367 [02:50<05:29,  1.36s/it]
#
# Embedding Batches:  34%|███▍      | 126/367 [02:51<05:24,  1.35s/it]
#
# Embedding Batches:  35%|███▍      | 127/367 [02:52<05:29,  1.37s/it]
#
# Embedding Batches:  35%|███▍      | 128/367 [02:53<05:03,  1.27s/it]
#
# Embedding Batches:  35%|███▌      | 129/367 [02:55<05:00,  1.26s/it]
#
# Embedding Batches:  35%|███▌      | 130/367 [02:56<05:12,  1.32s/it]
#
# Embedding Batches:  36%|███▌      | 131/367 [02:57<05:17,  1.34s/it]
#
# Embedding Batches:  36%|███▌      | 132/367 [02:59<04:59,  1.28s/it]
#
# Embedding Batches:  36%|███▌      | 133/367 [03:00<05:17,  1.36s/it]
#
# Embedding Batches:  37%|███▋      | 134/367 [03:01<04:52,  1.26s/it]
#
# Embedding Batches:  37%|███▋      | 135/367 [03:02<04:34,  1.18s/it]
#
# Embedding Batches:  37%|███▋      | 136/367 [03:03<04:43,  1.23s/it]
#
# Embedding Batches:  37%|███▋      | 137/367 [03:05<04:28,  1.17s/it]
#
# Embedding Batches:  38%|███▊      | 138/367 [03:06<04:33,  1.19s/it]
#
# Embedding Batches:  38%|███▊      | 139/367 [03:07<04:40,  1.23s/it]
#
# Embedding Batches:  38%|███▊      | 140/367 [03:08<04:44,  1.25s/it]
#
# Embedding Batches:  38%|███▊      | 141/367 [03:10<04:45,  1.27s/it]
#
# Embedding Batches:  39%|███▊      | 142/367 [03:11<05:01,  1.34s/it]
#
# Embedding Batches:  39%|███▉      | 143/367 [03:12<04:51,  1.30s/it]
#
# Embedding Batches:  39%|███▉      | 144/367 [03:13<04:27,  1.20s/it]
#
# Embedding Batches:  40%|███▉      | 145/367 [03:15<04:26,  1.20s/it]
#
# Embedding Batches:  40%|███▉      | 146/367 [03:16<04:20,  1.18s/it]
#
# Embedding Batches:  40%|████      | 147/367 [03:17<04:35,  1.25s/it]
#
# Embedding Batches:  40%|████      | 148/367 [03:18<04:37,  1.27s/it]
#
# Embedding Batches:  41%|████      | 149/367 [03:20<04:35,  1.26s/it]
#
# Embedding Batches:  41%|████      | 150/367 [03:21<04:42,  1.30s/it]
#
# Embedding Batches:  41%|████      | 151/367 [03:22<04:31,  1.26s/it]
#
# Embedding Batches:  41%|████▏     | 152/367 [03:24<04:31,  1.26s/it]
#
# Embedding Batches:  42%|████▏     | 153/367 [03:25<04:23,  1.23s/it]
#
# Embedding Batches:  42%|████▏     | 154/367 [03:26<04:37,  1.30s/it]
#
# Embedding Batches:  42%|████▏     | 155/367 [03:27<04:26,  1.26s/it]
#
# Embedding Batches:  43%|████▎     | 156/367 [03:29<04:23,  1.25s/it]
#
# Embedding Batches:  43%|████▎     | 157/367 [03:30<04:33,  1.30s/it]
#
# Embedding Batches:  43%|████▎     | 158/367 [03:31<04:24,  1.27s/it]
#
# Embedding Batches:  43%|████▎     | 159/367 [03:32<04:23,  1.27s/it]
#
# Embedding Batches:  44%|████▎     | 160/367 [03:35<05:17,  1.53s/it]
#
# Embedding Batches:  44%|████▍     | 161/367 [03:36<05:03,  1.47s/it]
#
# Embedding Batches:  44%|████▍     | 162/367 [03:38<05:19,  1.56s/it]
#
# Embedding Batches:  44%|████▍     | 163/367 [03:39<04:45,  1.40s/it]
#
# Embedding Batches:  45%|████▍     | 164/367 [03:40<04:54,  1.45s/it]
#
# Embedding Batches:  45%|████▍     | 165/367 [03:42<04:43,  1.40s/it]
#
# Embedding Batches:  45%|████▌     | 166/367 [03:43<04:47,  1.43s/it]
#
# Embedding Batches:  46%|████▌     | 167/367 [03:44<04:43,  1.42s/it]
#
# Embedding Batches:  46%|████▌     | 168/367 [03:46<04:36,  1.39s/it]
#
# Embedding Batches:  46%|████▌     | 169/367 [03:47<04:29,  1.36s/it]
#
# Embedding Batches:  46%|████▋     | 170/367 [03:48<04:25,  1.35s/it]
#
# Embedding Batches:  47%|████▋     | 171/367 [03:50<04:11,  1.29s/it]
#
# Embedding Batches:  47%|████▋     | 172/367 [03:51<04:17,  1.32s/it]
#
# Embedding Batches:  47%|████▋     | 173/367 [03:52<04:04,  1.26s/it]
#
# Embedding Batches:  47%|████▋     | 174/367 [03:53<04:03,  1.26s/it]
#
# Embedding Batches:  48%|████▊     | 175/367 [03:55<04:07,  1.29s/it]
#
# Embedding Batches:  48%|████▊     | 176/367 [03:56<04:06,  1.29s/it]
#
# Embedding Batches:  48%|████▊     | 177/367 [03:57<04:07,  1.30s/it]
#
# Embedding Batches:  49%|████▊     | 178/367 [03:59<04:04,  1.30s/it]
#
# Embedding Batches:  49%|████▉     | 179/367 [04:00<04:02,  1.29s/it]
#
# Embedding Batches:  49%|████▉     | 180/367 [04:01<04:21,  1.40s/it]
#
# Embedding Batches:  49%|████▉     | 181/367 [04:03<04:20,  1.40s/it]
#
# Embedding Batches:  50%|████▉     | 182/367 [04:04<04:21,  1.41s/it]
#
# Embedding Batches:  50%|████▉     | 183/367 [04:06<04:18,  1.41s/it]
#
# Embedding Batches:  50%|█████     | 184/367 [04:07<04:16,  1.40s/it]
#
# Embedding Batches:  50%|█████     | 185/367 [04:09<04:17,  1.42s/it]
#
# Embedding Batches:  51%|█████     | 186/367 [04:10<04:08,  1.37s/it]
#
# Embedding Batches:  51%|█████     | 187/367 [04:11<04:03,  1.35s/it]
#
# Embedding Batches:  51%|█████     | 188/367 [04:12<04:00,  1.34s/it]
#
# Embedding Batches:  51%|█████▏    | 189/367 [04:14<04:19,  1.46s/it]
#
# Embedding Batches:  52%|█████▏    | 190/367 [04:15<03:55,  1.33s/it]
#
# Embedding Batches:  52%|█████▏    | 191/367 [04:17<04:01,  1.37s/it]
#
# Embedding Batches:  52%|█████▏    | 192/367 [04:18<03:57,  1.35s/it]
#
# Embedding Batches:  53%|█████▎    | 193/367 [04:19<03:56,  1.36s/it]
#
# Embedding Batches:  53%|█████▎    | 194/367 [04:21<03:55,  1.36s/it]
#
# Embedding Batches:  53%|█████▎    | 195/367 [04:22<03:50,  1.34s/it]
#
# Embedding Batches:  53%|█████▎    | 196/367 [04:23<03:30,  1.23s/it]
#
# Embedding Batches:  54%|█████▎    | 197/367 [04:24<03:33,  1.26s/it]
#
# Embedding Batches:  54%|█████▍    | 198/367 [04:26<03:41,  1.31s/it]
#
# Embedding Batches:  54%|█████▍    | 199/367 [04:28<04:34,  1.63s/it]
#
# Embedding Batches:  54%|█████▍    | 200/367 [04:29<04:19,  1.56s/it]
#
# Embedding Batches:  55%|█████▍    | 201/367 [04:31<04:01,  1.46s/it]
#
# Embedding Batches:  55%|█████▌    | 202/367 [04:32<03:59,  1.45s/it]
#
# Embedding Batches:  55%|█████▌    | 203/367 [04:34<03:57,  1.45s/it]
#
# Embedding Batches:  56%|█████▌    | 204/367 [04:36<04:19,  1.59s/it]
#
# Embedding Batches:  56%|█████▌    | 205/367 [04:37<03:50,  1.42s/it]
#
# Embedding Batches:  56%|█████▌    | 206/367 [04:38<03:51,  1.44s/it]
#
# Embedding Batches:  56%|█████▋    | 207/367 [04:40<03:52,  1.45s/it]
#
# Embedding Batches:  57%|█████▋    | 208/367 [04:41<03:50,  1.45s/it]
#
# Embedding Batches:  57%|█████▋    | 209/367 [04:43<04:27,  1.69s/it]
#
# Embedding Batches:  57%|█████▋    | 210/367 [04:45<04:12,  1.61s/it]
#
# Embedding Batches:  57%|█████▋    | 211/367 [04:46<03:57,  1.52s/it]
#
# Embedding Batches:  58%|█████▊    | 212/367 [04:47<03:49,  1.48s/it]
#
# Embedding Batches:  58%|█████▊    | 213/367 [04:49<03:35,  1.40s/it]
#
# Embedding Batches:  58%|█████▊    | 214/367 [04:50<03:34,  1.40s/it]
#
# Embedding Batches:  59%|█████▊    | 215/367 [04:51<03:33,  1.40s/it]
#
# Embedding Batches:  59%|█████▉    | 216/367 [04:53<03:33,  1.42s/it]
#
# Embedding Batches:  59%|█████▉    | 217/367 [04:54<03:31,  1.41s/it]
#
# Embedding Batches:  59%|█████▉    | 218/367 [04:55<03:19,  1.34s/it]
#
# Embedding Batches:  60%|█████▉    | 219/367 [04:57<03:23,  1.38s/it]
#
# Embedding Batches:  60%|█████▉    | 220/367 [04:58<03:17,  1.34s/it]
#
# Embedding Batches:  60%|██████    | 221/367 [04:59<03:11,  1.31s/it]
#
# Embedding Batches:  60%|██████    | 222/367 [05:01<03:17,  1.36s/it]
#
# Embedding Batches:  61%|██████    | 223/367 [05:02<03:19,  1.38s/it]
#
# Embedding Batches:  61%|██████    | 224/367 [05:04<03:15,  1.37s/it]
#
# Embedding Batches:  61%|██████▏   | 225/367 [05:05<03:09,  1.34s/it]
#
# Embedding Batches:  62%|██████▏   | 226/367 [05:06<03:12,  1.37s/it]
#
# Embedding Batches:  62%|██████▏   | 227/367 [05:08<03:11,  1.36s/it]
#
# Embedding Batches:  62%|██████▏   | 228/367 [05:09<03:11,  1.38s/it]
#
# Embedding Batches:  62%|██████▏   | 229/367 [05:10<02:59,  1.30s/it]
#
# Embedding Batches:  63%|██████▎   | 230/367 [05:12<03:01,  1.33s/it]
#
# Embedding Batches:  63%|██████▎   | 231/367 [05:13<03:00,  1.33s/it]
#
# Embedding Batches:  63%|██████▎   | 232/367 [05:14<02:59,  1.33s/it]
#
# Embedding Batches:  63%|██████▎   | 233/367 [05:16<03:02,  1.36s/it]
#
# Embedding Batches:  64%|██████▍   | 234/367 [05:17<02:55,  1.32s/it]
#
# Embedding Batches:  64%|██████▍   | 235/367 [05:19<03:28,  1.58s/it]
#
# Embedding Batches:  64%|██████▍   | 236/367 [05:20<03:04,  1.41s/it]
#
# Embedding Batches:  65%|██████▍   | 237/367 [05:21<03:01,  1.40s/it]
#
# Embedding Batches:  65%|██████▍   | 238/367 [05:23<02:57,  1.38s/it]
#
# Embedding Batches:  65%|██████▌   | 239/367 [05:24<02:58,  1.40s/it]
#
# Embedding Batches:  65%|██████▌   | 240/367 [05:25<02:49,  1.34s/it]
#
# Embedding Batches:  66%|██████▌   | 241/367 [05:27<02:50,  1.35s/it]
#
# Embedding Batches:  66%|██████▌   | 242/367 [05:28<02:55,  1.40s/it]
#
# Embedding Batches:  66%|██████▌   | 243/367 [05:29<02:39,  1.29s/it]
#
# Embedding Batches:  66%|██████▋   | 244/367 [05:31<02:38,  1.29s/it]
#
# Embedding Batches:  67%|██████▋   | 245/367 [05:32<02:36,  1.29s/it]
#
# Embedding Batches:  67%|██████▋   | 246/367 [05:33<02:37,  1.30s/it]
#
# Embedding Batches:  67%|██████▋   | 247/367 [05:35<02:34,  1.29s/it]
#
# Embedding Batches:  68%|██████▊   | 248/367 [05:36<02:22,  1.20s/it]
#
# Embedding Batches:  68%|██████▊   | 249/367 [05:37<02:29,  1.27s/it]
#
# Embedding Batches:  68%|██████▊   | 250/367 [05:39<02:54,  1.49s/it]
#
# Embedding Batches:  68%|██████▊   | 251/367 [05:40<02:45,  1.43s/it]
#
# Embedding Batches:  69%|██████▊   | 252/367 [05:42<02:45,  1.44s/it]
#
# Embedding Batches:  69%|██████▉   | 253/367 [05:43<02:44,  1.45s/it]
#
# Embedding Batches:  69%|██████▉   | 254/367 [05:45<02:47,  1.48s/it]
#
# Embedding Batches:  69%|██████▉   | 255/367 [05:46<02:39,  1.43s/it]
#
# Embedding Batches:  70%|██████▉   | 256/367 [05:47<02:36,  1.41s/it]
#
# Embedding Batches:  70%|███████   | 257/367 [05:49<02:32,  1.39s/it]
#
# Embedding Batches:  70%|███████   | 258/367 [05:50<02:32,  1.40s/it]
#
# Embedding Batches:  71%|███████   | 259/367 [05:52<02:36,  1.45s/it]
#
# Embedding Batches:  71%|███████   | 260/367 [05:53<02:33,  1.43s/it]
#
# Embedding Batches:  71%|███████   | 261/367 [05:55<02:30,  1.42s/it]
#
# Embedding Batches:  71%|███████▏  | 262/367 [05:56<02:26,  1.40s/it]
#
# Embedding Batches:  72%|███████▏  | 263/367 [05:57<02:22,  1.37s/it]
#
# Embedding Batches:  72%|███████▏  | 264/367 [05:59<02:21,  1.37s/it]
#
# Embedding Batches:  72%|███████▏  | 265/367 [06:00<02:13,  1.31s/it]
#
# Embedding Batches:  72%|███████▏  | 266/367 [06:02<02:29,  1.48s/it]
#
# Embedding Batches:  73%|███████▎  | 267/367 [06:03<02:21,  1.42s/it]
#
# Embedding Batches:  73%|███████▎  | 268/367 [06:04<02:17,  1.39s/it]
#
# Embedding Batches:  73%|███████▎  | 269/367 [06:06<02:17,  1.40s/it]
#
# Embedding Batches:  74%|███████▎  | 270/367 [06:07<02:20,  1.44s/it]
#
# Embedding Batches:  74%|███████▍  | 271/367 [06:08<02:13,  1.39s/it]
#
# Embedding Batches:  74%|███████▍  | 272/367 [06:10<02:09,  1.36s/it]
#
# Embedding Batches:  74%|███████▍  | 273/367 [06:11<02:06,  1.35s/it]
#
# Embedding Batches:  75%|███████▍  | 274/367 [06:12<01:55,  1.24s/it]
#
# Embedding Batches:  75%|███████▍  | 275/367 [06:14<02:15,  1.47s/it]
#
# Embedding Batches:  75%|███████▌  | 276/367 [06:15<02:09,  1.42s/it]
#
# Embedding Batches:  75%|███████▌  | 277/367 [06:17<02:07,  1.41s/it]
#
# Embedding Batches:  76%|███████▌  | 278/367 [06:18<02:03,  1.39s/it]
#
# Embedding Batches:  76%|███████▌  | 279/367 [06:19<02:01,  1.38s/it]
#
# Embedding Batches:  76%|███████▋  | 280/367 [06:21<01:58,  1.37s/it]
#
# Embedding Batches:  77%|███████▋  | 281/367 [06:22<02:06,  1.47s/it]
#
# Embedding Batches:  77%|███████▋  | 282/367 [06:24<02:00,  1.42s/it]
#
# Embedding Batches:  77%|███████▋  | 283/367 [06:25<01:52,  1.34s/it]
#
# Embedding Batches:  77%|███████▋  | 284/367 [06:26<01:51,  1.34s/it]
#
# Embedding Batches:  78%|███████▊  | 285/367 [06:28<01:50,  1.35s/it]
#
# Embedding Batches:  78%|███████▊  | 286/367 [06:29<01:48,  1.34s/it]
#
# Embedding Batches:  78%|███████▊  | 287/367 [06:30<01:48,  1.35s/it]
#
# Embedding Batches:  78%|███████▊  | 288/367 [06:32<01:45,  1.34s/it]
#
# Embedding Batches:  79%|███████▊  | 289/367 [06:33<01:43,  1.33s/it]
#
# Embedding Batches:  79%|███████▉  | 290/367 [06:34<01:42,  1.33s/it]
#
# Embedding Batches:  79%|███████▉  | 291/367 [06:36<01:47,  1.42s/it]
#
# Embedding Batches:  80%|███████▉  | 292/367 [06:37<01:46,  1.42s/it]
#
# Embedding Batches:  80%|███████▉  | 293/367 [06:39<01:43,  1.41s/it]
#
# Embedding Batches:  80%|████████  | 294/367 [06:40<01:40,  1.37s/it]
#
# Embedding Batches:  80%|████████  | 295/367 [06:41<01:40,  1.40s/it]
#
# Embedding Batches:  81%|████████  | 296/367 [06:43<01:40,  1.42s/it]
#
# Embedding Batches:  81%|████████  | 297/367 [06:44<01:34,  1.35s/it]
#
# Embedding Batches:  81%|████████  | 298/367 [06:45<01:27,  1.27s/it]
#
# Embedding Batches:  81%|████████▏ | 299/367 [06:47<01:33,  1.38s/it]
#
# Embedding Batches:  82%|████████▏ | 300/367 [06:48<01:30,  1.35s/it]
#
# Embedding Batches:  82%|████████▏ | 301/367 [06:50<01:30,  1.37s/it]
#
# Embedding Batches:  82%|████████▏ | 302/367 [06:51<01:27,  1.35s/it]
#
# Embedding Batches:  83%|████████▎ | 303/367 [06:52<01:30,  1.42s/it]
#
# Embedding Batches:  83%|████████▎ | 304/367 [06:53<01:22,  1.30s/it]
#
# Embedding Batches:  83%|████████▎ | 305/367 [06:55<01:19,  1.28s/it]
#
# Embedding Batches:  83%|████████▎ | 306/367 [06:56<01:18,  1.28s/it]
#
# Embedding Batches:  84%|████████▎ | 307/367 [06:57<01:16,  1.28s/it]
#
# Embedding Batches:  84%|████████▍ | 308/367 [06:59<01:18,  1.33s/it]
#
# Embedding Batches:  84%|████████▍ | 309/367 [07:00<01:13,  1.26s/it]
#
# Embedding Batches:  84%|████████▍ | 310/367 [07:01<01:15,  1.33s/it]
#
# Embedding Batches:  85%|████████▍ | 311/367 [07:02<01:07,  1.20s/it]
#
# Embedding Batches:  85%|████████▌ | 312/367 [07:04<01:08,  1.24s/it]
#
# Embedding Batches:  85%|████████▌ | 313/367 [07:05<01:05,  1.22s/it]
#
# Embedding Batches:  86%|████████▌ | 314/367 [07:06<01:08,  1.29s/it]
#
# Embedding Batches:  86%|████████▌ | 315/367 [07:08<01:08,  1.32s/it]
#
# Embedding Batches:  86%|████████▌ | 316/367 [07:09<01:14,  1.46s/it]
#
# Embedding Batches:  86%|████████▋ | 317/367 [07:11<01:11,  1.44s/it]
#
# Embedding Batches:  87%|████████▋ | 318/367 [07:12<01:07,  1.38s/it]
#
# Embedding Batches:  87%|████████▋ | 319/367 [07:13<01:02,  1.31s/it]
#
# Embedding Batches:  87%|████████▋ | 320/367 [07:14<01:01,  1.30s/it]
#
# Embedding Batches:  87%|████████▋ | 321/367 [07:15<00:57,  1.25s/it]
#
# Embedding Batches:  88%|████████▊ | 322/367 [07:17<00:57,  1.27s/it]
#
# Embedding Batches:  88%|████████▊ | 323/367 [07:18<00:58,  1.34s/it]
#
# Embedding Batches:  88%|████████▊ | 324/367 [07:20<00:56,  1.32s/it]
#
# Embedding Batches:  89%|████████▊ | 325/367 [07:21<00:56,  1.33s/it]
#
# Embedding Batches:  89%|████████▉ | 326/367 [07:22<00:54,  1.32s/it]
#
# Embedding Batches:  89%|████████▉ | 327/367 [07:24<00:53,  1.35s/it]
#
# Embedding Batches:  89%|████████▉ | 328/367 [07:25<00:53,  1.37s/it]
#
# Embedding Batches:  90%|████████▉ | 329/367 [07:27<00:53,  1.40s/it]
#
# Embedding Batches:  90%|████████▉ | 330/367 [07:28<00:49,  1.35s/it]
#
# Embedding Batches:  90%|█████████ | 331/367 [07:29<00:49,  1.38s/it]
#
# Embedding Batches:  90%|█████████ | 332/367 [07:31<00:55,  1.60s/it]
#
# Embedding Batches:  91%|█████████ | 333/367 [07:33<00:50,  1.49s/it]
#
# Embedding Batches:  91%|█████████ | 334/367 [07:34<00:47,  1.44s/it]
#
# Embedding Batches:  91%|█████████▏| 335/367 [07:35<00:44,  1.38s/it]
#
# Embedding Batches:  92%|█████████▏| 336/367 [07:36<00:42,  1.36s/it]
#
# Embedding Batches:  92%|█████████▏| 337/367 [07:38<00:39,  1.33s/it]
#
# Embedding Batches:  92%|█████████▏| 338/367 [07:39<00:39,  1.35s/it]
#
# Embedding Batches:  92%|█████████▏| 339/367 [07:40<00:34,  1.23s/it]
#
# Embedding Batches:  93%|█████████▎| 340/367 [07:41<00:31,  1.18s/it]
#
# Embedding Batches:  93%|█████████▎| 341/367 [07:42<00:32,  1.23s/it]
#
# Embedding Batches:  93%|█████████▎| 342/367 [07:44<00:31,  1.25s/it]
#
# Embedding Batches:  93%|█████████▎| 343/367 [07:45<00:30,  1.26s/it]
#
# Embedding Batches:  94%|█████████▎| 344/367 [07:46<00:30,  1.31s/it]
#
# Embedding Batches:  94%|█████████▍| 345/367 [07:48<00:28,  1.31s/it]
#
# Embedding Batches:  94%|█████████▍| 346/367 [07:49<00:27,  1.29s/it]
#
# Embedding Batches:  95%|█████████▍| 347/367 [07:50<00:26,  1.32s/it]
#
# Embedding Batches:  95%|█████████▍| 348/367 [07:52<00:24,  1.28s/it]
#
# Embedding Batches:  95%|█████████▌| 349/367 [07:54<00:29,  1.64s/it]
#
# Embedding Batches:  95%|█████████▌| 350/367 [07:55<00:25,  1.49s/it]
#
# Embedding Batches:  96%|█████████▌| 351/367 [07:57<00:23,  1.45s/it]
#
# Embedding Batches:  96%|█████████▌| 352/367 [07:58<00:21,  1.40s/it]
#
# Embedding Batches:  96%|█████████▌| 353/367 [07:59<00:18,  1.30s/it]
#
# Embedding Batches:  96%|█████████▋| 354/367 [08:00<00:15,  1.21s/it]
#
# Embedding Batches:  97%|█████████▋| 355/367 [08:01<00:15,  1.30s/it]
#
# Embedding Batches:  97%|█████████▋| 356/367 [08:03<00:15,  1.44s/it]
#
# Embedding Batches:  97%|█████████▋| 357/367 [08:05<00:14,  1.41s/it]
#
# Embedding Batches:  98%|█████████▊| 358/367 [08:06<00:12,  1.43s/it]
#
# Embedding Batches:  98%|█████████▊| 359/367 [08:07<00:11,  1.39s/it]
#
# Embedding Batches:  98%|█████████▊| 360/367 [08:09<00:09,  1.36s/it]
#
# Embedding Batches:  98%|█████████▊| 361/367 [08:10<00:08,  1.34s/it]
#
# Embedding Batches:  99%|█████████▊| 362/367 [08:11<00:06,  1.40s/it]
#
# Embedding Batches:  99%|█████████▉| 363/367 [08:13<00:05,  1.42s/it]
#
# Embedding Batches:  99%|█████████▉| 364/367 [08:14<00:04,  1.40s/it]
#
# Embedding Batches:  99%|█████████▉| 365/367 [08:16<00:02,  1.42s/it]
#
# Embedding Batches: 100%|█████████▉| 366/367 [08:17<00:01,  1.43s/it]
#
# Embedding Batches: 100%|██████████| 367/367 [08:19<00:00,  1.36s/it]
# WARNING:urllib3.connectionpool:Retrying (Retry(total=6, connect=7, read=6, redirect=7, status=7)) after connection broken by 'RemoteDisconnected('Remote end closed connection without response')': /Shrijeet14/Comment-Analyzer.mlflow/api/2.0/mlflow/runs/create
# Training Stacking Model...
# Fitting model: 100%|██████████| 1/1 [33:30<00:00, 2010.89s/it]
# WARNING:urllib3.connectionpool:Retrying (Retry(total=6, connect=7, read=6, redirect=7, status=7)) after connection broken by 'RemoteDisconnected('Remote end closed connection without response')': /Shrijeet14/Comment-Analyzer.mlflow/api/2.0/mlflow/runs/get?run_uuid=80bc4db6cdc346a1a34bc1814ed69407&run_id=80bc4db6cdc346a1a34bc1814ed69407
# 🏃 View run Stacking_with_OpenAI_Embeddings at: https://dagshub.com/Shrijeet14/Comment-Analyzer.mlflow/#/experiments/8/runs/80bc4db6cdc346a1a34bc1814ed69407
# 🧪 View experiment at: https://dagshub.com/Shrijeet14/Comment-Analyzer.mlflow/#/experiments/8
#               precision    recall  f1-score   support
#
#           -1       0.63      0.52      0.57      1647
#            0       0.76      0.81      0.78      2510
#            1       0.75      0.77      0.76      3176
#
#     accuracy                           0.73      7333
#    macro avg       0.71      0.70      0.70      7333
# weighted avg       0.72      0.73      0.72      7333
